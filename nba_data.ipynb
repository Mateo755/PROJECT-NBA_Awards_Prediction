# %%
from creating_datasets import get_players_stats
import pandas as pd

# %%
df = get_players_stats("2020")
df.head()
# Out:
# /home/mateusz/VScode/PROJECT-NBA_Awards_Prediction/get_table_by_id.py:23: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_html(str(table))[0]
# /home/mateusz/VScode/PROJECT-NBA_Awards_Prediction/get_table_by_id.py:23: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_html(str(table))[0]
#                   Player   Age Team Pos     G    GS  MP_avg    FG   FGA  \
# 0           James Harden  30.0  HOU  SG  68.0  68.0    36.5   9.9  22.3
# 1           Bradley Beal  26.0  WAS  SG  57.0  57.0    36.0  10.4  22.9
# 2         Damian Lillard  29.0  POR  PG  66.0  66.0    37.5   9.5  20.4
# 3             Trae Young  21.0  ATL  PG  60.0  60.0    35.3   9.1  20.8
# ...

# %%
df.to_csv("csv/players_stats_preview.csv", index=False)

# %%
df.columns
# Out:
# Index(['Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP_avg', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'Awards_per_game', 'MP_total', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%',
#        'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS',
#        'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Awards_adv'],
#       dtype='object')
